# %% [markdown]
# # Prueba Titanic

# %%
import pandas as pd
import numpy as np

path="titanic3.csv"
data=pd.read_csv(path)

data.fillna(axis='rows',method='ffill')

data.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %% [markdown]
# # Carga de datos por la funcion Open
#
# ### Primero tenemos que crear un diccionario con claves igual al nombre de cada columna y valor el contenido de dichas filas
# ### Luego agregarlos al DataFrame
#
# ## Este procesamiento es util cuando se manejan datos de gran tamaño

# %%
data_dict=dict()
columns=list()
with open(path,'r') as f:
    columns=f.readline().strip().split(',')
    ncols=len(columns)
    data_dict={ col :list() 
               for col in columns}
    for line in f:
        datos=line.strip().split(',')
        for i in range(ncols):
            valor=datos[i] if len(datos[i])!=0 else np.nan
            data_dict[columns[i]].append(valor)
# luego de haber obtenido las columnas en un diccionario, estamos listos para rellenarlos

print(data_dict.keys())

# %%
data=pd.DataFrame(data_dict)
data
# Out:
#      pclass survived        name                                       sex  \
# 0         1        1      "Allen                   Miss. Elisabeth Walton"
# 1         1        1    "Allison                    Master. Hudson Trevor"
# 2         1        0    "Allison                      Miss. Helen Loraine"
# 3         1        0    "Allison              Mr. Hudson Joshua Creighton"
# 4         1        0    "Allison   Mrs. Hudson J C (Bessie Waldo Daniels)"
# ...     ...      ...         ...                                       ...
# 1304      3        0     "Zabour                             Miss. Hileni"
# 1305      3        0     "Zabour                            Miss. Thamine"
# 1306      3        0   "Zakarian                          Mr. Mapriededer"
# 1307      3        0   "Zakarian                                Mr. Ortin"
# 1308      3        0  "Zimmerman                                  Mr. Leo"
#
# ...

# %% [markdown]
# # Leer datos desde una URL

# %%
import pandas as pd
url_data="https://github.com/joanby/python-ml-course/blob/master/datasets/iris/iris.csv"
data=pd.read_csv(url_data)
data.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-6-614d7032685a> in <module>
#       1 import pandas as pd
#       2 url_data="https://github.com/joanby/python-ml-course/blob/master/datasets/iris/iris.csv"
# ----> 3 data=pd.read_csv(url_data)
#       4 data.head()
#
# ...

# %% [markdown]
# # Lectura de archivos excel

# %%
data=pd.read_excel('path o ruta relativa','Nombre-alterno')

# %% [markdown]
# # Plot y visualizacion de Datos

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
data=pd.read_csv(r"D:\User\UdemyProyectos\python-ml-course\datasets\customer-churn-model\Tab Customer Churn Model.txt",sep='\t')
data.head()

# %%
data.plot(kind='scatter',x='Night Mins',y='Night Charge')

# %%
#usaremos plt.subplots() para obtener un objeto 'fig' y otro 'axes', representanndo a la figura y otro un arreglo de tuplas
#que contiene un axis=Gafico
data.head()

# %%
fig,axes=plt.subplots(2,2)

data.plot(kind='scatter',y='Night Mins',x='Night Charge',ax=axes[0][0])
data.plot(kind='scatter',y='Night Mins',x='Day Mins',ax=axes[1][1])

# %% [markdown]
# # boxplot en Matplotlib.pyplot

# %%
data.boxplot(data['Days Calls'])
