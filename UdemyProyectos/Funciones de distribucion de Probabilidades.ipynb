# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
data=np.random.uniform(1,200,size=200)
plt.hist(data,bins=int(np.abs(np.ceil(1-np.log2(200)))),histtype='stepfilled',color='green',alpha=0.3)
# Out:
# (array([28., 36., 34., 31., 34., 37.]),
#  array([  3.03762598,  35.72126715,  68.40490833, 101.08854951,
#         133.77219068, 166.45583186, 199.13947304]),
#  <a list of 1 Patch objects>)

# %%
data=np.random.randn(100)
x=range(100)

# %%
plt.plot(x,data,'-r',label='Aleatorio')

# %%
plt.hist(data,bins=30,histtype='stepfilled')
# Out:
# (array([ 3.,  1.,  3.,  8.,  1.,  1.,  4.,  3.,  2.,  7.,  3.,  2., 10.,
#          7.,  4.,  7.,  7.,  5.,  7.,  1.,  3.,  1.,  4.,  0.,  1.,  1.,
#          1.,  1.,  1.,  1.]),
#  array([-1.64943004, -1.51821112, -1.38699221, -1.25577329, -1.12455438,
#         -0.99333546, -0.86211655, -0.73089763, -0.59967872, -0.4684598 ,
#         -0.33724089, -0.20602197, -0.07480306,  0.05641586,  0.18763477,
#          0.31885369,  0.4500726 ,  0.58129152,  0.71251043,  0.84372935,
#          0.97494826,  1.10616718,  1.23738609,  1.36860501,  1.49982392,
#          1.63104284,  1.76226175,  1.89348067,  2.02469958,  2.1559185 ,
#          2.28713741]),
#  <a list of 1 Patch objects>)

# %% [markdown]
# ### Dummy Data Sets

# %%
import pandas as pd
n=100
data=pd.DataFrame({
    'A':np.random.randn(n),
    'B':1.5+2.5*np.random.randn(n),
    'C':np.random.uniform(0,1,n)
})

data.head()
# Out:
#           A         B         C
# 0  2.196923 -0.006879  0.947339
# 1 -1.560285  1.302449  0.829666
# 2 -1.152263  1.273808  0.114750
# 3  2.294028 -0.298429  0.154869
# 4  0.368780  5.096874  0.600626

# %% [markdown]
# ### Agrupacion de datos por categoria

# %%
import os

path=r"D:\User\UdemyProyectos\python-ml-course\datasets"
path_data=r"customer-churn-model\Tab Customer Churn Model.txt"
data=pd.read_csv(os.path.join(path,path_data),sep='\t')
data.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# ...

# %%
grouped_gender=data.groupby('State')

# %%
grouped_gender.groups
# Out:
# {'AK': Int64Index([  36,   38,   95,  138,  181,  282,  339,  350,  353,  505,  550,
#               657,  684,  718,  719,  812,  950,  953, 1024, 1054, 1094, 1162,
#              1224, 1260, 1342, 1417, 1589, 1682, 1803, 1884, 1987, 2071, 2083,
#              2101, 2222, 2265, 2269, 2270, 2367, 2418, 2475, 2571, 2627, 2752,
#              2807, 2902, 2929, 3088, 3137, 3236, 3241, 3283],
#             dtype='int64'),
#  'AL': Int64Index([   5,  112,  135,  169,  219,  239,  272,  278,  288,  326,  332,
#               450,  469,  491,  497,  514,  531,  540,  590,  750,  776,  788,
#               805,  822,  843,  859,  934,  949,  958, 1015, 1026, 1090, 1104,
#              1129, 1131, 1152, 1274, 1428, 1464, 1613, 1661, 1662, 1767, 1780,
#              1839, 1902, 2081, 2135, 2155, 2172, 2180, 2212, 2317, 2329, 2334,
#              2348, 2446, 2494, 2595, 2601, 2634, 2644, 2699, 2738, 2748, 2749,
#              2827, 2845, 2858, 2939, 2992, 3017, 3048, 3058, 3078, 3095, 3128,
# ...

# %%
grouped_gender.get_group('NY')
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 15      NY             161        415  351-7269         no         no
# 77      NY             144        408  360-1171         no         no
# 136     NY              75        415  374-8525         no        yes
# 182     NY              67        408  405-2888         no        yes
# 186     NY             106        408  422-1471         no         no
# ...    ...             ...        ...       ...        ...        ...
# 3219    NY             150        415  421-6268         no        yes
# 3227    NY             209        415  369-8703         no         no
# 3257    NY             171        415  412-6245         no         no
# 3275    NY             120        510  405-5083         no        yes
# 3310    NY              94        415  363-1123         no         no
#
#       VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  \
# ...

# %%
data_pro=data.groupby(['State','Area Code','VMail Plan']).aggregate({'VMail Plan':'count','Day Mins':[np.min,np.max,np.sum]})
data_pro.head(10)
# Out:
#                            VMail Plan Day Mins
#                                 count     amin   amax     sum
# State Area Code VMail Plan
# AK    408       no                 10     83.2  278.4  1755.2
#                 yes                 4    139.3  245.0   680.6
#       415       no                 14     58.2  262.3  2550.5
#                 yes                10     75.8  278.0  1918.2
#       510       no                 12    123.7  238.4  2052.5
#                 yes                 2    135.8  183.2   319.0
# AL    408       no                 18     86.8  270.0  3529.8
#                 yes                 7     68.7  265.9  1221.4
#       415       no                 30     98.8  237.7  5337.8
#                 yes                10     95.0  264.4  1999.1

# %%
# Out:
# pandas.core.frame.DataFrame
